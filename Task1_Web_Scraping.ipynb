# %% [markdown]
# <a href="https://colab.research.google.com/github/SyedaFarahJaseemZaidi-ds/CodeAlpha_Data_Analytics_Tasks/blob/main/Task1_Web_Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from google.colab import files

# 1. Target Website
url = "http://books.toscrape.com/"

# 2. Extract Data
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

titles, prices, availabilities = [], [], []
books = soup.find_all("article", class_="product_pod")

for book in books:
    titles.append(book.h3.a["title"])
    prices.append(book.find("p", class_="price_color").text)
    availabilities.append(book.find("p", class_="instock availability").text.strip())

# 3. Create DataFrame and Save CSV
df = pd.DataFrame({
    "Book Title": titles,
    "Price": prices,
    "Availability": availabilities
})

# Save locally in Colab
df.to_csv("scraped_books.csv", index=False)
print("✅ Web scraping complete!")

# 4. AUTOMATICALLY DOWNLOAD CSV TO YOUR PHONE
files.download("scraped_books.csv")
# Out:
# ✅ Web scraping complete!
